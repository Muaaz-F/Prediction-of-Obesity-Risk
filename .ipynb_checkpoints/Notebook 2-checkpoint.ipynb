# %%
import pandas as pd
import numpy as np

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from xgboost import XGBClassifier

# %%
modified_train_df = pd.read_csv('modified_train.csv')
modified_test_df = pd.read_csv('modified_test.csv')

# %%
modified_train_df.head()
# Out:
#    id  Gender        Age    Height      Weight  \
# 0   0     1.0  24.443011  1.699998   81.669950
# 1   1     0.0  18.000000  1.560000   57.000000
# 2   2     0.0  18.000000  1.711460   50.165754
# 3   3     0.0  20.952737  1.710730  131.274851
# 4   4     1.0  31.641081  1.914186   93.798055
#
#    family_history_with_overweight  FAVC      FCVC       NCP  CAEC  SMOKE  \
# 0                             1.0   1.0  2.000000  2.983297   1.0    0.0
# 1                             1.0   1.0  2.000000  3.000000   2.0    0.0
# 2                             1.0   1.0  1.880534  1.411685   1.0    0.0
# 3                             1.0   1.0  3.000000  3.000000   1.0    0.0
# 4                             1.0   1.0  2.679664  1.971472   1.0    0.0
#
#        CH2O  SCC       FAF       TUE  CALC  MTRANS           NObeyesdad  \
# 0  2.763573  0.0  0.000000  0.976473   1.0     0.0  Overweight_Level_II
# 1  2.000000  0.0  1.000000  1.000000   0.0     1.0        Normal_Weight
# 2  1.910378  0.0  0.866045  1.673584   0.0     0.0  Insufficient_Weight
# 3  1.674061  0.0  1.467863  0.780199   1.0     0.0     Obesity_Type_III
# 4  1.979848  0.0  1.967973  0.931721   1.0     0.0  Overweight_Level_II
#
#          BMI
# 0  28.259565
# 1  23.422091
# 2  17.126706
# 3  44.855798
# 4  25.599151

# %%
X_train = modified_train_df.drop(columns=['NObeyesdad'])
y_train = modified_train_df['NObeyesdad']
X_test = modified_test_df

# %%
train_id = X_train['id']
test_id = X_test['id']

X_train.drop(columns=['id'], inplace=True)
X_test.drop(columns=['id'], inplace=True)

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
classifiers = {
    "Decision Tree": DecisionTreeClassifier(),
    "Random Forest": RandomForestClassifier(),
    "Support Vector Machine": SVC(kernel='linear', decision_function_shape='ovr'),
    "K-Nearest Neighbors": KNeighborsClassifier(),
    "Gaussian Naive Bayes": GaussianNB(),
    "Gradient Boosting": GradientBoostingClassifier(),
}

# %%
X_train_split, X_val, y_train_split, y_val = train_test_split(X_train_scaled, y_train, test_size=0.2, random_state=42)

# %%
for name, classifier in classifiers.items():
    print(f"Training {name}...")

    classifier.fit(X_train_split, y_train_split)
    
    y_pred_val = classifier.predict(X_val)
    
    accuracy_val = accuracy_score(y_val, y_pred_val)
    print(f"Accuracy of {name}: {accuracy_val:.4f}")
    
    print(f"Classification Report of {name} (Validation):\n{classification_report(y_val, y_pred_val)}")
    
    print(f"Confusion Matrix of {name} (Validation):\n{confusion_matrix(y_val, y_pred_val)}")
    
    if hasattr(classifier, 'feature_importances_'):
        feature_importances = pd.DataFrame({'Feature': X_train.columns, 'Importance': classifier.feature_importances_})
        feature_importances.sort_values(by='Importance', ascending=False, inplace=True)
        print(f"Feature Importances of {name}:\n{feature_importances}")
    
    print("--------------------------------------------------")
# Out:
# Training Decision Tree...
# Accuracy of Decision Tree: 0.8389
# Classification Report of Decision Tree (Validation):
#                      precision    recall  f1-score   support
#
# Insufficient_Weight       0.91      0.90      0.90       524
#       Normal_Weight       0.80      0.80      0.80       626
#      Obesity_Type_I       0.80      0.81      0.80       543
#     Obesity_Type_II       0.95      0.93      0.94       657
#    Obesity_Type_III       0.99      1.00      0.99       804
#  Overweight_Level_I       0.63      0.64      0.64       484
# Overweight_Level_II       0.69      0.68      0.69       514
#
#            accuracy                           0.84      4152
#           macro avg       0.82      0.82      0.82      4152
#        weighted avg       0.84      0.84      0.84      4152
#
# Confusion Matrix of Decision Tree (Validation):
# [[470  48   0   0   0   6   0]
#  [ 45 502   4   0   1  68   6]
#  [  2   2 439  22   2  25  51]
#  [  0   0  36 611   1   0   9]
#  [  0   0   2   1 800   0   1]
#  [  2  63  13   2   3 310  91]
#  [  0  16  56   9   1  81 351]]
# Feature Importances of Decision Tree:
#                            Feature  Importance
# 16                             BMI    0.575456
# 3                           Weight    0.161700
# 0                           Gender    0.052609
# 1                              Age    0.041885
# 6                             FCVC    0.034324
# 2                           Height    0.026715
# 12                             FAF    0.019462
# 10                            CH2O    0.018443
# 13                             TUE    0.014591
# 7                              NCP    0.013134
# 14                            CALC    0.010272
# 8                             CAEC    0.009126
# 5                             FAVC    0.009106
# 15                          MTRANS    0.004762
# 4   family_history_with_overweight    0.004189
# 11                             SCC    0.003688
# 9                            SMOKE    0.000537
# --------------------------------------------------
# Training Random Forest...
# Accuracy of Random Forest: 0.8986
# Classification Report of Random Forest (Validation):
#                      precision    recall  f1-score   support
#
# Insufficient_Weight       0.94      0.93      0.94       524
#       Normal_Weight       0.87      0.88      0.88       626
#      Obesity_Type_I       0.87      0.87      0.87       543
#     Obesity_Type_II       0.97      0.96      0.97       657
#    Obesity_Type_III       1.00      1.00      1.00       804
#  Overweight_Level_I       0.76      0.78      0.77       484
# Overweight_Level_II       0.80      0.79      0.80       514
#
#            accuracy                           0.90      4152
#           macro avg       0.89      0.89      0.89      4152
#        weighted avg       0.90      0.90      0.90      4152
#
# Confusion Matrix of Random Forest (Validation):
# [[488  33   0   0   0   2   1]
#  [ 27 553   0   0   0  42   4]
#  [  2   1 472  15   1  17  35]
#  [  0   0  20 634   2   0   1]
#  [  0   0   1   1 802   0   0]
#  [  1  40   9   0   0 376  58]
#  [  0  10  38   4   0  56 406]]
# Feature Importances of Random Forest:
#                            Feature  Importance
# 16                             BMI    0.331207
# 3                           Weight    0.252705
# 1                              Age    0.069437
# 6                             FCVC    0.063537
# 2                           Height    0.058824
# 0                           Gender    0.049524
# 10                            CH2O    0.030728
# 12                             FAF    0.024954
# 13                             TUE    0.023840
# 7                              NCP    0.021556
# 4   family_history_with_overweight    0.020663
# 14                            CALC    0.015847
# 8                             CAEC    0.015650
# 5                             FAVC    0.009019
# 15                          MTRANS    0.008490
# 11                             SCC    0.003240
# 9                            SMOKE    0.000780
# --------------------------------------------------
# Training Support Vector Machine...
# Accuracy of Support Vector Machine: 0.8721
# Classification Report of Support Vector Machine (Validation):
#                      precision    recall  f1-score   support
#
# Insufficient_Weight       0.89      0.94      0.91       524
#       Normal_Weight       0.87      0.82      0.84       626
#      Obesity_Type_I       0.84      0.85      0.84       543
#     Obesity_Type_II       0.96      0.97      0.96       657
#    Obesity_Type_III       1.00      1.00      1.00       804
#  Overweight_Level_I       0.71      0.75      0.73       484
# Overweight_Level_II       0.74      0.70      0.72       514
#
#            accuracy                           0.87      4152
#           macro avg       0.86      0.86      0.86      4152
#        weighted avg       0.87      0.87      0.87      4152
#
# Confusion Matrix of Support Vector Machine (Validation):
# [[491  30   0   0   0   2   1]
#  [ 58 511   0   0   0  56   1]
#  [  2   0 460  22   1   9  49]
#  [  0   0  19 636   1   0   1]
#  [  0   0   1   1 802   0   0]
#  [  1  39   8   0   0 361  75]
#  [  0   9  62   4   0  79 360]]
# --------------------------------------------------
# Training K-Nearest Neighbors...
# Accuracy of K-Nearest Neighbors: 0.7693
# Classification Report of K-Nearest Neighbors (Validation):
#                      precision    recall  f1-score   support
#
# Insufficient_Weight       0.77      0.80      0.79       524
#       Normal_Weight       0.60      0.66      0.63       626
#      Obesity_Type_I       0.72      0.77      0.75       543
#     Obesity_Type_II       0.94      0.94      0.94       657
#    Obesity_Type_III       1.00      1.00      1.00       804
#  Overweight_Level_I       0.55      0.47      0.51       484
# Overweight_Level_II       0.64      0.58      0.61       514
#
#            accuracy                           0.77      4152
#           macro avg       0.75      0.75      0.74      4152
#        weighted avg       0.77      0.77      0.77      4152
#
# Confusion Matrix of K-Nearest Neighbors (Validation):
# [[421  96   1   0   0   5   1]
#  [ 96 415   8   0   0  73  34]
#  [  4   9 418  26   2  31  53]
#  [  0   3  29 616   0   0   9]
#  [  0   0   0   2 800   1   1]
#  [ 20 121  46   0   0 227  70]
#  [  4  49  75  11   0  78 297]]
# --------------------------------------------------
# Training Gaussian Naive Bayes...
# Accuracy of Gaussian Naive Bayes: 0.7724
# Classification Report of Gaussian Naive Bayes (Validation):
#                      precision    recall  f1-score   support
#
# Insufficient_Weight       0.81      0.92      0.86       524
#       Normal_Weight       0.82      0.65      0.73       626
#      Obesity_Type_I       0.61      0.64      0.63       543
#     Obesity_Type_II       0.81      0.94      0.87       657
#    Obesity_Type_III       0.96      1.00      0.98       804
#  Overweight_Level_I       0.66      0.53      0.59       484
# Overweight_Level_II       0.58      0.56      0.57       514
#
#            accuracy                           0.77      4152
#           macro avg       0.75      0.75      0.75      4152
#        weighted avg       0.77      0.77      0.77      4152
#
# Confusion Matrix of Gaussian Naive Bayes (Validation):
# [[483  35   0   0   4   1   1]
#  [111 410   0   0  20  69  16]
#  [  2   0 349 129   5  14  44]
#  [  0   0  31 620   0   1   5]
#  [  0   0   2   1 800   1   0]
#  [  3  41  36   0   2 255 147]
#  [  0  13 153  14   1  43 290]]
# --------------------------------------------------
# Training Gradient Boosting...
# Accuracy of Gradient Boosting: 0.9017
# Classification Report of Gradient Boosting (Validation):
#                      precision    recall  f1-score   support
#
# Insufficient_Weight       0.93      0.94      0.94       524
#       Normal_Weight       0.87      0.88      0.88       626
#      Obesity_Type_I       0.90      0.87      0.89       543
#     Obesity_Type_II       0.97      0.97      0.97       657
#    Obesity_Type_III       1.00      1.00      1.00       804
#  Overweight_Level_I       0.78      0.77      0.78       484
# Overweight_Level_II       0.79      0.80      0.79       514
#
#            accuracy                           0.90      4152
#           macro avg       0.89      0.89      0.89      4152
#        weighted avg       0.90      0.90      0.90      4152
#
# Confusion Matrix of Gradient Boosting (Validation):
# [[493  28   0   0   0   2   1]
#  [ 30 553   0   0   0  38   5]
#  [  3   1 474  11   1  10  43]
#  [  1   0  13 639   2   0   2]
#  [  0   0   1   1 802   0   0]
#  [  1  42   6   0   0 374  61]
#  [  0   9  33   5   1  57 409]]
# Feature Importances of Gradient Boosting:
#                            Feature  Importance
# 16                             BMI    0.651391
# 3                           Weight    0.155443
# 0                           Gender    0.102080
# 1                              Age    0.019437
# 10                            CH2O    0.015531
# 6                             FCVC    0.015066
# 2                           Height    0.009193
# 14                            CALC    0.006022
# 7                              NCP    0.005758
# 8                             CAEC    0.005260
# 5                             FAVC    0.004153
# 13                             TUE    0.003951
# 12                             FAF    0.003206
# 15                          MTRANS    0.001395
# 4   family_history_with_overweight    0.001101
# 11                             SCC    0.000991
# 9                            SMOKE    0.000023
# --------------------------------------------------

# %% [markdown]
# The best model is **Gradient Boosting Classifier** with an accuracy of **`0.9017`**
